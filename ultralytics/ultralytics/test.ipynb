# %%
import torch
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.model.eval()

dummy = torch.randn(1, 3, 640, 640)

with torch.no_grad():
    preds = model.model(dummy)

print(type(preds))
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 5.1MB/s 1.2s.2s<0.1s1.9s
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       7 dummy = torch.randn(1, 3, 640, 640)
#       9 with torch.no_grad():
# ---> 10     preds = model.model(dummy)
#      12 print(type(preds))
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/tasks.py:137, in BaseModel.forward(self, x, *args, **kwargs)
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
#     136     return self.loss(x, *args, **kwargs)
# --> 137 return self.predict(x, *args, **kwargs)
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/tasks.py:154, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     152 if augment:
#     153     return self._predict_augment(x)
# --> 154 return self._predict_once(x, profile, visualize, embed)
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/tasks.py:176, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     174 if profile:
#     175     self._profile_one_layer(m, x, dt)
# --> 176 x = m(x)  # run
#     177 y.append(x if m.i in self.save else None)  # save output
#     178 if visualize:
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/modules/head.py:128, in Detect.forward(self, x)
#     126 for i in range(self.nl):
#     127     pred = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
# --> 128     vis = torch.sigmoid(self.cv_vis[i](x[i]))
#     129     x[i] = torch.cat((pred, vis), 1)
#     131     if not self.training:
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1940, in Module.__getattr__(self, name)
#    1938     if name in modules:
#    1939         return modules[name]
# -> 1940 raise AttributeError(
#    1941     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1942 )
#
# AttributeError: 'Detect' object has no attribute 'cv_vis'

# %%
from ultralytics import YOLO
import torch

model = YOLO("ultralytics/cfg/models/v8/yolov8n.yaml")
model.model.eval()

dummy = torch.randn(1, 3, 640, 640)

with torch.no_grad():
    preds = model.model(dummy)

print("✅ Forward pass OK")


## Need to run in terminal.
# Out:
# Output shape: torch.Size([1, 145, 32, 32])
# Output shape: torch.Size([1, 145, 16, 16])
# Output shape: torch.Size([1, 145, 8, 8])
# [DEBUG] Head output shape (scale 0): torch.Size([1, 145, 80, 80])
# Output shape: torch.Size([1, 145, 80, 80])
# [DEBUG] Head output shape (scale 1): torch.Size([1, 145, 40, 40])
# Output shape: torch.Size([1, 145, 40, 40])
# [DEBUG] Head output shape (scale 2): torch.Size([1, 145, 20, 20])
# Output shape: torch.Size([1, 145, 20, 20])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 10
#       7 dummy = torch.randn(1, 3, 640, 640)
#       9 with torch.no_grad():
# ---> 10     preds = model.model(dummy)
#      12 print("✅ Forward pass OK")
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/tasks.py:137, in BaseModel.forward(self, x, *args, **kwargs)
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
#     136     return self.loss(x, *args, **kwargs)
# --> 137 return self.predict(x, *args, **kwargs)
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/tasks.py:154, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     152 if augment:
#     153     return self._predict_augment(x)
# --> 154 return self._predict_once(x, profile, visualize, embed)
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/tasks.py:176, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     174 if profile:
#     175     self._profile_one_layer(m, x, dt)
# --> 176 x = m(x)  # run
#     177 y.append(x if m.i in self.save else None)  # save output
#     178 if visualize:
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/modules/head.py:139, in Detect.forward(self, x)
#     137 if self.training:  # Training path
#     138     return x
# --> 139 y = self._inference(x)
#     140 return y if self.export else (y, x)
#
# File /Volumes/storage_dc/ml_learning/divagar_ws/ultralytics/ultralytics/nn/modules/head.py:181, in Detect._inference(self, x)
#     178     self.anchors, self.strides = (x.transpose(0, 1) for x in make_anchors(x, self.stride, 0.5))
#     179     self.shape = shape
# --> 181 box, cls = x_cat.split((self.reg_max * 4, self.nc), 1)
#     182 dbox = self.decode_bboxes(self.dfl(box), self.anchors.unsqueeze(0)) * self.strides
#     183 return torch.cat((dbox, cls.sigmoid()), 1)
#
# File /Volumes/storage_dc/ml_learning/tf_env/lib/python3.11/site-packages/torch/_tensor.py:1053, in Tensor.split(self, split_size, dim)
#    1051     return torch._VF.split(self, split_size, dim)  # type: ignore[attr-defined]
#    1052 else:
# -> 1053     return torch._VF.split_with_sizes(self, split_size, dim)
#
# RuntimeError: split_with_sizes expects split_sizes to sum exactly to 145 (input tensor's size at dimension 1), but got split_sizes=[64, 80]
